# %% [markdown]
# #### TIMELINE
#
# **Week 1**
#
# - Understand quantum compilers and how they work on circuits. What are the most common approaches to quantum compilers for different technologies?
#     -  [Quantum Compilers](https://arxiv.org/pdf/2112.00187)
#     - [Quarl: Learning-Based Quantum Circuit Optimizer](https://arxiv.org/abs/2307.10120#:~:text=transformations%20that%20temporarily%20decrease%20performance,evaluation%20shows%20that%20Quarl%20significantly)
#     - [Quantum Compiling with Reinforcement Learning on a Superconducting Processor](https://arxiv.org/html/2406.12195v1#:~:text=reinforcement%20learning%20%28RL%29,based%20compilers)
#     - Understand problems with current compilers (algorithmically \& hardware)
#     - Understand solutions
#
#     - Setup environment, compile and execute a simple circuit on TKET
